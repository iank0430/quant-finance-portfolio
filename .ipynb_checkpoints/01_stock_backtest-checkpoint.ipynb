# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# 1. Download stock data
ticker = "AAPL"  # Apple example
data = yf.download(ticker, start="2020-01-01", end="2025-01-01")

# 2. Calculate moving averages
data['SMA50'] = data['Close'].rolling(50).mean()
data['SMA200'] = data['Close'].rolling(200).mean()

# 3. Plot the strategy
plt.figure(figsize=(12,6))
plt.plot(data['Close'], label="Price")
plt.plot(data['SMA50'], label="50-day SMA")
plt.plot(data['SMA200'], label="200-day SMA")
plt.legend()
plt.title(f"{ticker} - Simple Moving Average Strategy")
plt.show()
# Out:
# /var/folders/y6/phmfh8916vl1r2cph6pmjmq40000gn/T/ipykernel_12961/3406053309.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(ticker, start="2020-01-01", end="2025-01-01")
# [*********************100%***********************]  1 of 1 completed
